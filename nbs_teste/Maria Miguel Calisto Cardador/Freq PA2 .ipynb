# %% [markdown]
# Nome da aluna(o): Maria Cardador
#
# Número da aluna(o) : 2021137306

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
measurements_df = pd.read_csv("measurements.csv")
measurements_df.head(3)
# Out:
#           measurement_time  gadget_id  vibration_x  vibration_y  pressure  \
# 0  2020-07-15 00:00:00.000          1            3            7      16.0
# 1  2020-07-15 01:00:00.000          1            8            3      12.0
# 2  2020-07-15 01:59:59.990          1           10            8      20.0
#
#    temperature  Unnamed: 10  Unnamed: 11
# 0    44.114437          NaN          NaN
# 1    34.395177          NaN          NaN
# 2    38.280705          NaN          NaN

# %% [markdown]
# Q1 - Efectuar o parsing do campo measurement_time para datetime
# [3 valores]

# %%
measurements_df = pd.read_csv("measurements.csv", parse_dates = ['measurement_time'])
measurements_df.head(8)
# Out:
#          measurement_time  gadget_id  vibration_x  vibration_y  pressure  \
# 0 2020-07-15 00:00:00.000          1            3            7      16.0
# 1 2020-07-15 01:00:00.000          1            8            3      12.0
# 2 2020-07-15 01:59:59.990          1           10            8      20.0
# 3 2020-07-15 02:59:59.985          1            6            5      20.0
# 4 2020-07-15 03:59:59.980          1            6            9      16.0
# 5 2020-07-15 04:59:59.975          1            2            6      10.0
# 6 2020-07-15 05:59:59.970          1            8           10      10.0
# 7 2020-07-15 06:59:59.965          1            9            5      17.0
#
#    temperature  Unnamed: 10  Unnamed: 11
# 0    44.114437          NaN          NaN
# 1    34.395177          NaN          NaN
# 2    38.280705          NaN          NaN
# 3    41.878215          NaN          NaN
# 4    39.257268          NaN          NaN
# 5    38.927343          NaN          NaN
# ...

# %%
measurements_df.dtypes
# Out:
# measurement_time    datetime64[ns]
# gadget_id                    int64
# vibration_x                  int64
# vibration_y                  int64
# pressure                   float64
# temperature                float64
# Unnamed: 10                float64
# Unnamed: 11                float64
# dtype: object

# %% [markdown]
# Q2 - Retirar definitivamente (drop) os campos unnamed* do dataframe
# [2 valores]

# %%
measurements_df.drop(["Unnamed: 10", "Unnamed: 11"], axis = 1, inplace = True)
measurements_df.head(8)
# Out:
#          measurement_time  gadget_id  vibration_x  vibration_y  pressure  \
# 0 2020-07-15 00:00:00.000          1            3            7      16.0
# 1 2020-07-15 01:00:00.000          1            8            3      12.0
# 2 2020-07-15 01:59:59.990          1           10            8      20.0
# 3 2020-07-15 02:59:59.985          1            6            5      20.0
# 4 2020-07-15 03:59:59.980          1            6            9      16.0
# 5 2020-07-15 04:59:59.975          1            2            6      10.0
# 6 2020-07-15 05:59:59.970          1            8           10      10.0
# 7 2020-07-15 06:59:59.965          1            9            5      17.0
#
#    temperature
# 0    44.114437
# 1    34.395177
# 2    38.280705
# 3    41.878215
# 4    39.257268
# 5    38.927343
# 6    36.826310
# 7    30.692898

# %% [markdown]
# Q3 - Ordenar o dataframe de forma ascendente pelo campo measurement_time [2 valores]

# %%
measurements_df = df_measurements.sort_values(by = ['measurement_time'], ascending = [True])
measurements_df.head(8)
# Out:
#        measurement_time  gadget_id  vibration_x  vibration_y  pressure  \
# 0   2020-07-15 00:00:00          1            3            7      16.0
# 336 2020-07-15 00:00:00          3            3            8      11.0
# 168 2020-07-15 00:00:00          2            3           10      16.0
# 840 2020-07-15 00:00:00          6            7            6      12.0
# 672 2020-07-15 00:00:00          5            4            7      12.0
# 504 2020-07-15 00:00:00          4            3            7      12.0
# 841 2020-07-15 01:00:00          6            3            2      12.5
# 1   2020-07-15 01:00:00          1            8            3      12.0
#
#      temperature
# 0      44.114437
# 336    40.427740
# 168    22.300000
# 840    75.874521
# 672    81.125342
# 504    72.867296
# 841    74.502775
# 1      34.395177

# %% [markdown]
# Q4 - Escreva a função para obter estas estatísticas descritivas (novo dataframe)
# [1 valor]

# %%
estatisticas_df = measurements_df.describe()
estatisticas_df
# Out:
#          gadget_id  vibration_x  vibration_y     pressure  temperature
# count  1008.000000  1008.000000  1008.000000  1008.000000  1008.000000
# mean      3.500000     5.508929     5.439484    14.979167    59.813215
# std       1.708673     2.657533     2.727678     2.516295    22.320829
# min       1.000000     1.000000     0.000000    10.000000    11.463147
# 25%       2.000000     3.000000     3.000000    12.500000    37.091100
# 50%       3.500000     6.000000     5.000000    15.000000    71.200480
# 75%       5.000000     8.000000     7.000000    16.000000    77.606296
# max       6.000000    10.000000    10.000000    20.000000   109.816490

# %% [markdown]
# Q5 - Qual o valor do desvio padrão (std) do campo temperature ? (guarde-o numa variavel)
# [1 valor]

# %%
std_temperature = estatisticas_df.loc["std","temperature"]
std_temperature
# Out:
# 22.32082924549669

# %% [markdown]
# Q6 - Qual o valor da média (mean) do campo pressure (mudei segundo o professor) ? (guarde-o numa variavel)
# [1 valor]

# %%
mean_pressure = estatisticas_df.loc["mean","pressure"]
mean_pressure
# Out:
# 14.979166666666666

# %% [markdown]
# Q7 - Falha é um estado quando se verificam as condições (&)
#
# -vibration_y >= 7
# -temperature > que o valor std do campo temperature
# -pressure > que o valor mean do campo pressure
#
# escreva o código para obtermos esses registos
# [4 valores]

# %%
condicionado_df = measurements_df [(measurements_df.vibration_y>=7) & (measurements_df.temperature>std_temperature) & (measurements_df.pressure>mean_pressure)]
condicionado_df.head(12)
# Out:
#            measurement_time  gadget_id  vibration_x  vibration_y  pressure  \
# 0   2020-07-15 00:00:00.000          1            3            7      16.0
# 337 2020-07-15 01:00:00.000          3            9            9      19.0
# 2   2020-07-15 01:59:59.990          1           10            8      20.0
# 676 2020-07-15 03:59:59.980          5            7            9      16.0
# 4   2020-07-15 03:59:59.980          1            6            9      16.0
# 677 2020-07-15 04:59:59.975          5            7            9      18.0
# 845 2020-07-15 04:59:59.975          6            5            7      18.0
# 509 2020-07-15 04:59:59.975          4            2            9      18.0
# 175 2020-07-15 06:59:59.965          2            8            9      15.0
# 512 2020-07-15 07:59:59.960          4            5           10      15.0
# 680 2020-07-15 07:59:59.960          5            2           10      15.0
# ...

# %% [markdown]
# Novo csv

# %%
failures_df = pd.read_csv("failures.csv", parse_dates = ['failure_time'])
failures_df.head(3)
# Out:
#                    failure_time  gadget_id
# 0 2020-07-15 09:56:03.974006640          1
# 1 2020-07-15 21:49:25.197701400          1
# 2 2020-07-16 00:51:15.832103640          1

# %%
failures_df = failures_df.sort_values(by=['failure_time'], ascending = [True])
failures_df.head()
# Out:
#                     failure_time  gadget_id
# 52 2020-07-15 05:31:44.776014200          4
# 72 2020-07-15 05:48:58.383388460          5
# 53 2020-07-15 06:42:44.569051620          4
# 14 2020-07-15 07:11:50.319233260          2
# 39 2020-07-15 09:33:48.330967860          3

# %% [markdown]
# Q8 - Efectue o agupamento (groupby) pelo campo gadget_id e calcule (count) a quantidade de ocorrência de cada tipo de gadget
# [3 valores]

# %%
gadget_gb= failures_df.groupby(["gadget_id"]).count()
gadget_gb
# Out:
#            failure_time
# gadget_id
# 1                    14
# 2                    25
# 3                    13
# 4                    20
# 5                    25
# 6                     8

# %% [markdown]
# Q9 - Crie uma gráfico com os dados de objecto (groupby): barras, sem legenda e um título
# [3 valores]

# %%
gadget_gb.plot.bar(title = "Nº de falhas por gadget" , legend = False)
# Out:
# <AxesSubplot:title={'center':'Nº de falhas por gadget'}, xlabel='gadget_id'>
